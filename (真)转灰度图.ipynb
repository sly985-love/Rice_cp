# %%
from PIL import Image
import cv2
from pathlib import Path
import numpy as np

# %matplotlib inline
root = Path("bacterialblight_complex_10.png")
img = Image.open(root)
iimg = np.array(img)
# wai_root = Path('D:\水稻数据\水稻病害\东格鲁病')
# path_list = [path for path in root.iterdir()]
# img_path = root / 'new'
# if not img_path.exists():
#     img_path.mkdir()

# %%
palette_mine = [[0,0,0],[53,119,181],[255,0,0],[170,170,255],[245,128,6]]
npl = np.array(palette_mine)
new_p = npl.flatten()
ima = Image.open('blast_51.png')
# ima = np.array(ima)
imag = ima.convert('L')

imag.save('re1.png')
nimg = np.array(imag)
# while len(palette_mine) < 256:
#     palette_mine.append([0,0,0])
# print(len(palette_mine))
# npl = np.array(palette_mine)
# new_p = npl.flatten()

# %%
# 新数据集的转换
label = {'background': 0, 'leaf': 1, 'brownspot': 2, 'blast': 3, 'bacterialblight': 4, 'tungro': 5, 'Healthy': 6}
root = Path(r'E:\data\ricedata_v3.0\BrownSpot_150_3\SegmentationClass')
img_list = [path for path in root.iterdir()]
for img_path in img_list:
    img = Image.open(img_path)
    imgL = img.convert('L')
    w, h = imgL.size
    nimgL = np.array(imgL)
    for j in range(w):
        for i in range(h):
            if nimgL[i][j] == 0:
                continue
            # elif img[i][j] == 180:
            #     img[i][j] = label['bacterialblight']
            elif nimgL[i][j] == 106:
                nimgL[i][j] = label['leaf']
            elif nimgL[i][j] == 3:
                nimgL[i][j] = label['brownspot']
    img_pil = Image.fromarray(nimgL,mode='L')
    img_pil.save(img_path)
    print(img_path)
# Out:
# E:\data\ricedata_v3.0\bb150\SegmentationClass\BACTERIALBLIGHT_001.png
# E:\data\ricedata_v3.0\bb150\SegmentationClass\BACTERIALBLIGHT_003.png
# E:\data\ricedata_v3.0\bb150\SegmentationClass\BACTERIALBLIGHT_007.png
# E:\data\ricedata_v3.0\bb150\SegmentationClass\BACTERIALBLIGHT_009.png
# E:\data\ricedata_v3.0\bb150\SegmentationClass\BACTERIALBLIGHT_011.png
# E:\data\ricedata_v3.0\bb150\SegmentationClass\BACTERIALBLIGHT_023.png
# E:\data\ricedata_v3.0\bb150\SegmentationClass\BACTERIALBLIGHT_025.png
# E:\data\ricedata_v3.0\bb150\SegmentationClass\BACTERIALBLIGHT_026.png
# E:\data\ricedata_v3.0\bb150\SegmentationClass\BACTERIALBLIGHT_030.png
# E:\data\ricedata_v3.0\bb150\SegmentationClass\BACTERIALBLIGHT_032.png
# E:\data\ricedata_v3.0\bb150\SegmentationClass\BACTERIALBLIGHT_034.png
# E:\data\ricedata_v3.0\bb150\SegmentationClass\BACTERIALBLIGHT_036.png
# E:\data\ricedata_v3.0\bb150\SegmentationClass\BACTERIALBLIGHT_038.png
# ...

# %%
# 新数据集的转换
label = {'background': 0, 'leaf': 1, 'brownspot': 2, 'blast': 3, 'bacterialblight': 4, 'tungro': 5, 'Healthy': 6}
root = Path(r'E:\data\ricedata_v3.0\BacterialBlight_150_3\SegmentationClass')
img_list = [path for path in root.iterdir()]
for img_path in img_list:
    if img_path.suffix() =='.png':
        img = Image.open(img_path)
        imgL = img.convert('L')
        w, h = imgL.size
        nimgL = np.array(imgL)
        for j in range(w):
            for i in range(h):
                if nimgL[i][j] == 0:
                    continue
                # elif img[i][j] == 180:
                #     img[i][j] = label['bacterialblight']
                elif nimgL[i][j] == 106:
                    nimgL[i][j] = label['leaf']
                elif nimgL[i][j] == 149:
                    nimgL[i][j] = label['bacterialblight']
        img_pil = Image.fromarray(nimgL,mode='L')
        img_pil.save(img_path)
        print(img_path)

# %%
label = {'background': 0, 'leaf': 1, 'brownspot': 2, 'blast': 3, 'bacterialblight': 4, 'tungro': 5, 'Healthy': 6}
root = Path(r'E:\data\ricedata_v3.0\Blast_150_3\SegmentationClass')
img_list = [path for path in root.iterdir()]
for img_path in img_list:
    if img_path.suffix =='.png':
        img = Image.open(img_path)
        imgL = img.convert('L')
        w, h = imgL.size
        nimgL = np.array(imgL)
        for j in range(w):
            for i in range(h):
                if nimgL[i][j] == 0:
                    continue
                # elif img[i][j] == 180:
                #     img[i][j] = label['bacterialblight']
                elif nimgL[i][j] == 106:
                    nimgL[i][j] = label['leaf']
                elif nimgL[i][j] == 149:
                    nimgL[i][j] = label['blast']
        img_pil = Image.fromarray(nimgL,mode='L')
        img_pil.save(img_path)
        print(img_path)
# Out:
# E:\data\ricedata_v3.0\Blast_150_3\SegmentationClass\BLAST1_001.png
# E:\data\ricedata_v3.0\Blast_150_3\SegmentationClass\BLAST1_001_0.png
# E:\data\ricedata_v3.0\Blast_150_3\SegmentationClass\BLAST1_001_1.png
# E:\data\ricedata_v3.0\Blast_150_3\SegmentationClass\BLAST1_002.png
# E:\data\ricedata_v3.0\Blast_150_3\SegmentationClass\BLAST1_002_0.png
# E:\data\ricedata_v3.0\Blast_150_3\SegmentationClass\BLAST1_002_1.png
# E:\data\ricedata_v3.0\Blast_150_3\SegmentationClass\BLAST1_003.png
# E:\data\ricedata_v3.0\Blast_150_3\SegmentationClass\BLAST1_003_0.png
# E:\data\ricedata_v3.0\Blast_150_3\SegmentationClass\BLAST1_003_1.png
# E:\data\ricedata_v3.0\Blast_150_3\SegmentationClass\BLAST1_004.png
# E:\data\ricedata_v3.0\Blast_150_3\SegmentationClass\BLAST1_004_0.png
# E:\data\ricedata_v3.0\Blast_150_3\SegmentationClass\BLAST1_004_1.png
# E:\data\ricedata_v3.0\Blast_150_3\SegmentationClass\BLAST1_005.png
# E:\data\ricedata_v3.0\Blast_150_3\SegmentationClass\BLAST1_005_0.png
# ...

# %%
label = {'background': 0, 'leaf': 1, 'brownspot': 2, 'blast': 3, 'bacterialblight': 4, 'tungro': 5, 'Healthy': 6}
root = Path(r'E:\data\ricedata_v3.0\BrownSpot_150_3\SegmentationClass')
img_list = [path for path in root.iterdir()]
for img_path in img_list:
    img = Image.open(img_path)
    imgL = img.convert('L')
    w, h = imgL.size
    nimgL = np.array(imgL)
    for j in range(w):
        for i in range(h):
            if nimgL[i][j] == 0:
                continue
            # elif img[i][j] == 180:
            #     img[i][j] = label['bacterialblight']
            elif nimgL[i][j] == 106:
                nimgL[i][j] = label['leaf']
            elif nimgL[i][j] == 149:
                nimgL[i][j] = label['brownspot']
    img_pil = Image.fromarray(nimgL,mode='L')
    img_pil.save(img_path)
    print(img_path)
# Out:
# E:\data\ricedata_v3.0\BrownSpot_150_3\SegmentationClass\brownspot_orig_002.png
# E:\data\ricedata_v3.0\BrownSpot_150_3\SegmentationClass\brownspot_orig_002_0.png
# E:\data\ricedata_v3.0\BrownSpot_150_3\SegmentationClass\brownspot_orig_002_1.png
# E:\data\ricedata_v3.0\BrownSpot_150_3\SegmentationClass\brownspot_orig_003.png
# E:\data\ricedata_v3.0\BrownSpot_150_3\SegmentationClass\brownspot_orig_003_0.png
# E:\data\ricedata_v3.0\BrownSpot_150_3\SegmentationClass\brownspot_orig_003_1.png
# E:\data\ricedata_v3.0\BrownSpot_150_3\SegmentationClass\brownspot_orig_004.png
# E:\data\ricedata_v3.0\BrownSpot_150_3\SegmentationClass\brownspot_orig_004_0.png
# E:\data\ricedata_v3.0\BrownSpot_150_3\SegmentationClass\brownspot_orig_004_1.png
# E:\data\ricedata_v3.0\BrownSpot_150_3\SegmentationClass\brownspot_orig_005.png
# E:\data\ricedata_v3.0\BrownSpot_150_3\SegmentationClass\brownspot_orig_005_0.png
# E:\data\ricedata_v3.0\BrownSpot_150_3\SegmentationClass\brownspot_orig_005_1.png
# ...

# %%
class_name = {'class_bs': 123, 'class_b': 34, 'class_bb': 5}
tmp = zip(class_name.values(), class_name.keys())
final_class = max(tmp)
print(final_class[1])
# Out:
# class_bs

# %%
label = {'background': 0, 'leaf': 1, 'brownspot': 2, 'blast': 3, 'bacterialblight': 4, 'tungro': 5, 'Healthy': 6}
root = Path('D:\yesy\新数据集\cp增强数据\BrownSpot_135_1485\SegmentationClass')
img_list = [path for path in root.iterdir()]
for img_path in img_list:
    img = Image.open(img_path)
    imgL = img.convert('L')
    w, h = imgL.size
    nimgL = np.array(imgL)
    for j in range(w):
        for i in range(h):
            if nimgL[i][j] == 0:
                continue
            # elif img[i][j] == 180:
            #     img[i][j] = label['bacterialblight']
            elif nimgL[i][j] == 106:
                nimgL[i][j] = label['leaf']
            elif nimgL[i][j] == 149:
                nimgL[i][j] = label['brownspot']
    img_pil = Image.fromarray(nimgL,mode='L')
    img_pil.save(img_path)
    print(img_path)
# Out:
# D:\yesy\新数据集\cp增强数据\BrownSpot_135_1485\SegmentationClass\brownspot_orig_002.png
# D:\yesy\新数据集\cp增强数据\BrownSpot_135_1485\SegmentationClass\brownspot_orig_002_0.png
# D:\yesy\新数据集\cp增强数据\BrownSpot_135_1485\SegmentationClass\brownspot_orig_002_1.png
# D:\yesy\新数据集\cp增强数据\BrownSpot_135_1485\SegmentationClass\brownspot_orig_002_2.png
# D:\yesy\新数据集\cp增强数据\BrownSpot_135_1485\SegmentationClass\brownspot_orig_002_3.png
# D:\yesy\新数据集\cp增强数据\BrownSpot_135_1485\SegmentationClass\brownspot_orig_002_4.png
# D:\yesy\新数据集\cp增强数据\BrownSpot_135_1485\SegmentationClass\brownspot_orig_002_5.png
# D:\yesy\新数据集\cp增强数据\BrownSpot_135_1485\SegmentationClass\brownspot_orig_002_6.png
# D:\yesy\新数据集\cp增强数据\BrownSpot_135_1485\SegmentationClass\brownspot_orig_002_7.png
# D:\yesy\新数据集\cp增强数据\BrownSpot_135_1485\SegmentationClass\brownspot_orig_002_8.png
# D:\yesy\新数据集\cp增强数据\BrownSpot_135_1485\SegmentationClass\brownspot_orig_002_9.png
# ...

# %%
# 这里已经搞定转换了
# Out:
# BACTERIALBLIGHT_001_0.png
# BACTERIALBLIGHT_001_1.png
# BACTERIALBLIGHT_001_2.png
# BACTERIALBLIGHT_001_3.png
# BACTERIALBLIGHT_001_4.png
# BACTERIALBLIGHT_001_5.png
# BACTERIALBLIGHT_001_6.png
# BACTERIALBLIGHT_001_7.png
# BACTERIALBLIGHT_001_8.png
# BACTERIALBLIGHT_001_9.png
# BACTERIALBLIGHT_002_0.png
# BACTERIALBLIGHT_002_1.png
# BACTERIALBLIGHT_002_2.png
# BACTERIALBLIGHT_002_3.png
# BACTERIALBLIGHT_002_4.png
# BACTERIALBLIGHT_002_5.png
# BACTERIALBLIGHT_002_6.png
# BACTERIALBLIGHT_002_7.png
# BACTERIALBLIGHT_002_8.png
# BACTERIALBLIGHT_002_9.png
# BACTERIALBLIGHT_003_0.png
# BACTERIALBLIGHT_003_1.png
# BACTERIALBLIGHT_003_2.png
# BACTERIALBLIGHT_003_3.png
# BACTERIALBLIGHT_003_4.png
# BACTERIALBLIGHT_003_5.png
# BACTERIALBLIGHT_003_6.png
# BACTERIALBLIGHT_003_7.png
# BACTERIALBLIGHT_003_8.png
# BACTERIALBLIGHT_003_9.png
# BACTERIALBLIGHT_004_0.png
# BACTERIALBLIGHT_004_1.png
# BACTERIALBLIGHT_004_2.png
# BACTERIALBLIGHT_004_3.png
# BACTERIALBLIGHT_004_4.png
# ...

# %%
all_path = Path('D:\Program\python\Semantic Segmentation\deeplab_v3\data\SegmentationClass')
apath_list = [path for path in all_path.iterdir()]
for path in apath_list:
    if path.suffix == '.png':
        img = Image.open(str(path))
        img1 = img.convert('P',palette = Image.WEB)
        name = path.stem + '.png'
        new_img = str(all_path/'new'/name)
        img1.save(new_img)
        print(name)
# Out:
# BACTERIALBLIGHT_001.png
# BACTERIALBLIGHT_002.png
# BACTERIALBLIGHT_003.png
# BACTERIALBLIGHT_004.png
# BACTERIALBLIGHT_005.png
# BACTERIALBLIGHT_006.png
# BACTERIALBLIGHT_007.png
# BACTERIALBLIGHT_008.png
# BACTERIALBLIGHT_009.png
# BACTERIALBLIGHT_010.png
# BACTERIALBLIGHT_011.png
# BACTERIALBLIGHT_012.png
# BACTERIALBLIGHT_013.png
# BACTERIALBLIGHT_014.png
# BACTERIALBLIGHT_015.png
# BACTERIALBLIGHT_016.png
# BACTERIALBLIGHT_017.png
# BACTERIALBLIGHT_018.png
# BACTERIALBLIGHT_023.png
# BACTERIALBLIGHT_025.png
# BACTERIALBLIGHT_026.png
# BACTERIALBLIGHT_028.png
# BACTERIALBLIGHT_030.png
# BACTERIALBLIGHT_032.png
# BACTERIALBLIGHT_034.png
# BACTERIALBLIGHT_036.png
# BACTERIALBLIGHT_038.png
# BACTERIALBLIGHT_042.png
# BACTERIALBLIGHT_044.png
# BACTERIALBLIGHT_046.png
# BACTERIALBLIGHT_048.png
# BACTERIALBLIGHT_050.png
# BACTERIALBLIGHT_052.png
# BACTERIALBLIGHT_054.png
# BACTERIALBLIGHT_056.png
# BACTERIALBLIGHT_058.png
# BACTERIALBLIGHT_060.png
# BACTERIALBLIGHT_062.png
# ...

# %%
# %pip install imgviz
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (d:\programdata\anaconda3\envs\py37\lib\site-packages)
# WARNING: Ignoring invalid distribution -andb (d:\programdata\anaconda3\envs\py37\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\programdata\anaconda3\envs\py37\lib\site-packages)
# WARNING: Ignoring invalid distribution -andb (d:\programdata\anaconda3\envs\py37\lib\site-packages)
# ERROR: Exception:
# Traceback (most recent call last):
#   File "D:\ProgramData\Anaconda3\envs\py37\lib\site-packages\pip\_internal\cli\base_command.py", line 173, in _main
#     status = self.run(options, args)
#   File "D:\ProgramData\Anaconda3\envs\py37\lib\site-packages\pip\_internal\cli\req_command.py", line 203, in wrapper
#     return func(self, options, args)
# ...

# %%
import imgviz
import numpy as np
pathtest = 'D:\水稻数据\水稻病害\稻瘟病\label\BLAST1_106_pseudo.png'
mask = np.asarray(str(pathtest),dtype=np.uint8)
lbl_pil = Image.fromarray(mask.astype(np.uint32), mode="P")
colormap = imgviz.label_colormap()
lbl_pil.putpalette(colormap.flatten())
path = path.stem + '.png'
new_img = str(img_path/path)
lbl_pil.save(new_img)
print(path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23568\2338658160.py in <module>
#       2 import numpy as np
#       3 pathtest = 'D:\水稻数据\水稻病害\稻瘟病\label\BLAST1_106_pseudo.png'
# ----> 4 mask = np.asarray(str(pathtest),dtype=np.uint8)
#       5 lbl_pil = Image.fromarray(mask.astype(np.uint32), mode="P")
#       6 colormap = imgviz.label_colormap()
#
# ValueError: invalid literal for int() with base 10: 'D:\\水稻数据\\水稻病害\\稻瘟病\\label\\BLAST1_106_pseudo.png'

# %%
#换完名字可以溜了,哦，还要找原图

nei_path_list = [path for path in img_path.iterdir()]
for path in nei_path_list:
    
    if path.suffix == '.png':
        # if str(path.stem).split('_')[-1] == 'pseudo':
        new_name = "_".join(str(path.stem).split('_')[:-1])
        new_name = new_name + '.png'
        print(new_name)
        new_file = img_path / new_name
        path.rename(new_file)
        # else:
        #     path = path.unlink()
# Out:
# TUNGRO1.png
# TUNGRO1.png
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19664\1881361101.py in <module>
#      10         print(new_name)
#      11         new_file = img_path / new_name
# ---> 12         path.rename(new_file)
#      13         # else:
#      14         #     path = path.unlink()
#
# D:\ProgramData\Anaconda3\envs\npy37\lib\pathlib.py in rename(self, target)
#    1332         if self._closed:
#    1333             self._raise_closed()
# -> 1334         self._accessor.rename(self, target)
#    1335
#    1336     def replace(self, target):
#
# FileExistsError: [WinError 183] 当文件已存在时，无法创建该文件。: 'D:\\水稻数据\\水稻病害\\东格鲁病\\save\\new\\TUNGRO1_002.png' -> 'D:\\水稻数据\\水稻病害\\东格鲁病\\save\\new\\TUNGRO1.png'

# %%
#根据标签找到原图？
img_path = Path('D:\水稻数据\水稻病害\东格鲁病\img\新建文件夹')
wai_root = Path('D:\水稻数据\水稻病害\东格鲁病\save\\new')
nei_path_list = [path for path in img_path.iterdir()]
wai_path_list = [path for path in wai_root.iterdir()]
or_img = img_path / 'img'
if not or_img.exists():
    or_img.mkdir()
for path in nei_path_list:
    if path.suffix == '.jpg':
        img_name = str(path.stem) + '.png'
        img_old = wai_root / img_name
        img_new = or_img / img_name
        img_old.rename(img_new)

# %%
#根据找到的标签再找标签？
path_root = Path('D:\水稻数据\水稻病害\褐斑病\label')
path_dict = path_root / 'new'
path_list = [path for path in path_dict.iterdir()]
path_new = path_root / 'gt'
if not path_new.exists():
    path_new.mkdir()
for path in path_list:
    if path.suffix == '.png':
        img_name = str(path.stem) + '.png'
        img_old = path_root / img_name
        if not img_old.exists():
            break
        img_new = path_new / img_name
        img_old.rename(img_new)

# %%
from PIL import Image
import os
 
path = "D:\Program\python\Semantic Segmentation\BLSNet\label"  
all_images = os.listdir(path)
# print(all_images)
 
for image in all_images:
    image_path = os.path.join(path, image)
    img = Image.open(image_path)  # 打开图片
    img = img.convert("RGB")  # 4通道转化为rgb三通道
    save_path = 'D:\Program\python\Semantic Segmentation\BLSNet\label'
    img.save(save_path + image)

# %%
import os
import cv2

'''png格式常常是32位的RGBA格式，A代表透明度，
   光是更改图片后缀，不能改变图片的位数，
   需要在openCV中进行色彩空间的转换，
   将png格式的32位RGBA转为jpg格式的24位RGB'''


def convert2jpg(filename):  # 将彩色图转灰度图的函数
    img = cv2.imread(file_path + '/' + filename, 1)  # 1是以彩色图方式去读
    jpg_img = cv2.cvtColor(img, cv2.COLOR_BGRA2BGR)
    cv2.imwrite(out_path + '/' + filename, jpg_img)  # 保存在新文件夹下，且图名中加GRAY


file_path = "D:\Program\python\Semantic Segmentation\BLSNet\pytorch-UNet-master\data\JPEGImages"  # 输入文件夹
os.mkdir("D:\Program\python\Semantic Segmentation\BLSNet\pytorch-UNet-master\data\\nJPEGImages")  # 建立新的目录
out_path = "D:\Program\python\Semantic Segmentation\BLSNet\pytorch-UNet-master\data\\nJPEGImages"  # 设置为新目录为输出文件夹

for filename in os.listdir(file_path):  # 遍历输入路径，得到图片名
    print(filename)
    convert2jpg(filename)
# Out:
# brownspot_orig_001.jpg
# brownspot_orig_002.jpg
# brownspot_orig_003.jpg
# brownspot_orig_004.jpg
# brownspot_orig_005.jpg
# brownspot_orig_006.jpg
# brownspot_orig_007.jpg
# brownspot_orig_008.jpg
# brownspot_orig_009.jpg
# brownspot_orig_010.jpg
# brownspot_orig_011.jpg
# brownspot_orig_012.jpg
# brownspot_orig_013.jpg
# brownspot_orig_014.jpg
# brownspot_orig_015.jpg
# brownspot_orig_016.jpg
# brownspot_orig_017.jpg
# brownspot_orig_018.jpg
# brownspot_orig_019.jpg
# brownspot_orig_020.jpg
# brownspot_orig_021.jpg
# brownspot_orig_022.jpg
# brownspot_orig_023.jpg
# brownspot_orig_024.jpg
# brownspot_orig_025.jpg
# brownspot_orig_026.jpg
# brownspot_orig_027.jpg
# brownspot_orig_028.jpg
# brownspot_orig_029.jpg
# brownspot_orig_030.jpg
# brownspot_orig_031.jpg
# brownspot_orig_032.jpg
# brownspot_orig_033.jpg
# brownspot_orig_034.jpg
# brownspot_orig_035.jpg
# brownspot_orig_036.jpg
# brownspot_orig_037.jpg
# brownspot_orig_038.jpg
# brownspot_orig_039.jpg
# brownspot_orig_040.jpg
# ...
